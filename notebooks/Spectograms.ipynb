# %%
import os
import librosa
import librosa.display
import IPython.display as ipd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Loading audio files with Librosa

# %%
prefix = "../songs/"
cfm_file = prefix + "cfm.wav"
fancy_file  = prefix + "fancy.wav"
pw_file = prefix + "pw.wav"

cfm, sr = librosa.load(cfm_file)
fancy, _ = librosa.load(fancy_file)
pw, _ = librosa.load(pw_file)

# %% [markdown]
# ## Extracting Short-Time Fourier Transform

# %%
FRAME_SIZE = 2048
HOP_SIZE = 512
S_cfm = librosa.stft(cfm, n_fft=FRAME_SIZE, hop_length=HOP_SIZE)
S_fancy = librosa.stft(fancy, n_fft=FRAME_SIZE, hop_length=HOP_SIZE)
S_pw = librosa.stft(pw, n_fft=FRAME_SIZE, hop_length=HOP_SIZE)

# %% [markdown]
# ## Visualize the Spectrogram

# %%
def plot_spectrogram(Y, sr, hop_length, y_axis="linear"):
    plt.figure(figsize=(25, 10))
    librosa.display.specshow(Y, 
                             sr=sr, 
                             hop_length=hop_length, 
                             x_axis="time", 
                             y_axis=y_axis)
    plt.colorbar(format="%+2.f")

# %%
Y_cfm = librosa.power_to_db(np.abs(S_cfm) ** 2)
Y_fancy = librosa.power_to_db(np.abs(S_fancy) ** 2)
Y_pw = librosa.power_to_db(np.abs(S_pw) ** 2)

# %%
plot_spectrogram(Y_cfm, sr, HOP_SIZE, y_axis="log")

# %%
plot_spectrogram(Y_fancy, sr, HOP_SIZE, y_axis="log")

# %%
plot_spectrogram(Y_pw, sr, HOP_SIZE, y_axis="log")
